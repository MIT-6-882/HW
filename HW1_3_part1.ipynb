# %% [markdown]
# # 6.882 HW 1.3 Code Part 1
#
# See the problem set handout for instructions and deliverables.
#
# See HW1.1 Starter Code for dependency installation instructions.

# %%
# Install dependencies (run this once ever 12 hours)
# !pip install --upgrade git+https://github.com/tomsilver/pddlgym # Install most recent PDDLGym (must be from source!)
# !pip install tabulate
# !pip install pyperplan
# Out:
# Collecting git+https://github.com/tomsilver/pddlgym
#   Cloning https://github.com/tomsilver/pddlgym to /private/var/folders/2y/1l8njzj51qd7b7jnwzz5v2bm0000gn/T/pip-req-build-d_sk6bwo
# Requirement already satisfied, skipping upgrade: matplotlib in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pddlgym==0.0.2) (3.3.1)
# Requirement already satisfied, skipping upgrade: pillow in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pddlgym==0.0.2) (7.2.0)
# Requirement already satisfied, skipping upgrade: gym in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pddlgym==0.0.2) (0.17.2)
# Requirement already satisfied, skipping upgrade: imageio in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pddlgym==0.0.2) (2.9.0)
# Requirement already satisfied, skipping upgrade: scikit-image in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pddlgym==0.0.2) (0.17.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from matplotlib->pddlgym==0.0.2) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from matplotlib->pddlgym==0.0.2) (2.4.7)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from matplotlib->pddlgym==0.0.2) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from matplotlib->pddlgym==0.0.2) (1.2.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from matplotlib->pddlgym==0.0.2) (1.19.1)
# Requirement already satisfied, skipping upgrade: certifi>=2020.06.20 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from matplotlib->pddlgym==0.0.2) (2020.6.20)
# Requirement already satisfied, skipping upgrade: cloudpickle<1.4.0,>=1.2.0 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from gym->pddlgym==0.0.2) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyglet<=1.5.0,>=1.4.0 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from gym->pddlgym==0.0.2) (1.5.0)
# Requirement already satisfied, skipping upgrade: scipy in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from gym->pddlgym==0.0.2) (1.5.2)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from scikit-image->pddlgym==0.0.2) (2.4)
# Requirement already satisfied, skipping upgrade: PyWavelets>=1.1.1 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from scikit-image->pddlgym==0.0.2) (1.1.1)
# Requirement already satisfied, skipping upgrade: tifffile>=2019.7.26 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from scikit-image->pddlgym==0.0.2) (2020.9.3)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from python-dateutil>=2.1->matplotlib->pddlgym==0.0.2) (1.15.0)
# Requirement already satisfied, skipping upgrade: future in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pyglet<=1.5.0,>=1.4.0->gym->pddlgym==0.0.2) (0.18.2)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from networkx>=2.0->scikit-image->pddlgym==0.0.2) (4.4.2)
# Building wheels for collected packages: pddlgym
#   Building wheel for pddlgym (setup.py) ... done
#   Created wheel for pddlgym: filename=pddlgym-0.0.2-py3-none-any.whl size=5114477 sha256=e0a2e3c49062ac5737f7569ae0d1f304199c1e0890a315c9ced0e1fb8bb7bbe0
#   Stored in directory: /private/var/folders/2y/1l8njzj51qd7b7jnwzz5v2bm0000gn/T/pip-ephem-wheel-cache-qby4m2dn/wheels/70/00/da/84f1ea25112e85e8e4218a6905deae211edd977267c483f457
# Successfully built pddlgym
# Installing collected packages: pddlgym
#   Attempting uninstall: pddlgym
#     Found existing installation: pddlgym 0.0.2
#     Uninstalling pddlgym-0.0.2:
#       Successfully uninstalled pddlgym-0.0.2
# Successfully installed pddlgym-0.0.2
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/Users/tom/.pyenv/versions/3.6.7/bin/python3.6 -m pip install --upgrade pip' command.
# Requirement already satisfied: tabulate in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (0.8.7)
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/Users/tom/.pyenv/versions/3.6.7/bin/python3.6 -m pip install --upgrade pip' command.
# Requirement already satisfied: pyperplan in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (1.3)
# Requirement already satisfied: wheel in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pyperplan) (0.35.1)
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/Users/tom/.pyenv/versions/3.6.7/bin/python3.6 -m pip install --upgrade pip' command.

# %%
from collections import namedtuple, defaultdict, deque
from itertools import count, product
from tabulate import tabulate
import abc
import copy
import numpy as np
import heapq as hq
import pddlgym
from pddlgym.structs import Predicate, State, Type, LiteralConjunction
from pddlgym.parser import PDDLProblemParser
import functools
import tempfile
import os
import pyperplan
import time

# %% [markdown]
# ### Classes
# First we define some convenient abstract classes for Approach, Planner, Heuristic, and Featurizer.

# %%
class Approach:
    """Generic approach for learning and behaving in a domain.
    """
    @abc.abstractmethod
    def set_actions(self, actions):
        """Tell the approach what actions are available in the domain
        
        Parameters
        ----------
        actions : [ Any ]
            For a continuous action space, this would not work! If you are
            curious how one might handle actions more generally, see
            https://gym.openai.com/docs/#spaces.
        """
        raise NotImplementedError("Override me!")
    
    @abc.abstractmethod
    def reset(self, state):
        """Tell the approach to prepare to take actions from the given initial state.
        
        Parameters
        ----------
        state : pddlgym.State
            Note that the state contains the goal (state.goal).
            
        Returns
        -------
        info : dict
            Any logging or debugging info can go here.
        """
        raise NotImplementedError("Override me!")

    @abc.abstractmethod
    def step(self, state):
        """Ask the approach for an action to take given the input state.
        Assume that the action will be subsequently executed in the environment.
        
        Parameters
        ----------
        state : pddlgym.State
            Note that the state contains the goal (state.goal).
        
        Returns
        -------
        action : Any
        info : dict
            Any logging or debugging info can go here.
        """
        raise NotImplementedError("Override me!")

    @abc.abstractmethod
    def seed(self, seed):
        """Optionally set a random seed
        """
        raise NotImplementedError("Override me!")
        
    @abc.abstractmethod
    def train(self, env):
        """Some approaches learn. Others will do nothing for training.
        
        Parameters
        ----------
        env : pddlgym.PDDLEnv
            A training environment that encapsulates training problems.
        """
        raise NotImplementedError("Override me!")
        

class Planner:
    """Generic class for planning
    """
    @abc.abstractmethod
    def __call__(self, state):
        """Make a plan given the state.

        Parameters
        ----------
        state : pddlgym.State
            Note that the state contains the goal (state.goal).
        
        Returns
        -------
        actions : [ Any ]
            The plan
        info : dict
            Any logging or debugging info can go here.
        """
        raise NotImplementedError("Override me!")

    @abc.abstractmethod
    def set_actions(self, actions):
        """Tell the planner what actions are available in the domain
        
        Parameters
        ----------
        actions : [ Any ]
        """
        raise NotImplementedError("Override me!")
        

class Heuristic:
    """Generic class for heuristics
    """
    @abc.abstractmethod
    def __call__(self, node):
        """Return a heuristic value (estimated cost-to-go) given a search node.
        
        Parameters
        ----------
        node : AStar.Node

        Returns
        -------
        heuristic : float
        """
        raise NotImplementedError("Override me!")

    @abc.abstractmethod
    def set_actions(self, actions):
        """Tell the planner what actions are available in the domain
        
        Parameters
        ----------
        actions : [ Any ]
        """
        raise NotImplementedError("Override me!")

    @abc.abstractmethod
    def train(self, env):
        """Some heuristics are learnable. Others will do nothing for training.
        
        Parameters
        ----------
        env : pddlgym.PDDLEnv
            A training environment that encapsulates training problems.
        """
        raise NotImplementedError("Override me!")

# %%
class SearchApproach(Approach):
    """Make a plan and follow it
    """
    def __init__(self, planner, heuristic=None):
        self._planner = planner
        self._heuristic = heuristic
        self._actions = None
        self._plan = []
        self._rng = None

    def set_actions(self, actions):
        self._actions = actions
        self._planner.set_actions(actions)

    def reset(self, obs):
        self._plan, info = self._planner(obs)
        return info

    def step(self, obs):
        if not self._plan:
            print("Warning: step was called without a plan. Defaulting to random action.")
            return self._rng.choice(self._actions)
        return self._plan.pop(0)

    def seed(self, seed):
        self._rng = np.random.RandomState(seed)
        if isinstance(self._heuristic, Heuristic):
            self._heuristic.seed(seed)
        
    def train(self, env):
        if isinstance(self._heuristic, Heuristic):
            self._heuristic.train(env)

# %%
class AStar(Planner):
    """Planning with A* search
    """
    
    Node = namedtuple("Node", ["state", "parent", "action", "g"])

    def __init__(self, successor_fn, check_goal_fn, heuristic=None, timeout=100):
        self._get_successor_state = successor_fn
        self._check_goal = check_goal_fn
        self._heuristic = heuristic or (lambda s : 0)
        self._timeout = timeout
        self._actions = None
        
    def __call__(self, state, verbose=True):
        return self._get_plan(state, verbose=verbose)

    def set_actions(self, actions):
        self._actions = actions
        if isinstance(self._heuristic, Heuristic):
            self._heuristic.set_actions(actions)

    def _get_plan(self, state, verbose=True):
        start_time = time.time()
        queue = []
        state_to_best_g = defaultdict(lambda : float("inf"))
        tiebreak = count()

        root_node = self.Node(state=state, parent=None, action=None, g=0)
        hq.heappush(queue, (self._get_priority(root_node), next(tiebreak), root_node))
        num_expansions = 0

        while len(queue) > 0 and (time.time() - start_time < self._timeout):
            _, _, node = hq.heappop(queue)
            # If we already found a better path here, don't bother
            if state_to_best_g[node.state] < node.g:
                continue
            # If the goal holds, return
            if self._check_goal(node.state):
                if verbose:
                    print("\nPlan found!")
                return self._finish_plan(node), {'node_expansions' : num_expansions}
            num_expansions += 1
            if verbose:
                print(f"Expanding node {num_expansions}", end='\r', flush=True)
            # Generate successors
            for action, child_state in self._get_successors(node.state):
                # If we already found a better path to child, don't bother
                if state_to_best_g[child_state] <= node.g+1:
                    continue
                # Add new node
                child_node = self.Node(state=child_state, parent=node, action=action, g=node.g+1)
                priority = self._get_priority(child_node)
                hq.heappush(queue, (priority, next(tiebreak), child_node))
                state_to_best_g[child_state] = child_node.g

        if verbose:
            print("Warning: planning failed.")
        return [], {'node_expansions' : num_expansions}
    
    def _get_successors(self, state):
        for action in self._actions:
            next_state = self._get_successor_state(state, action)
            yield action, next_state

    def _finish_plan(self, node):
        plan = []
        while node.parent is not None:
            plan.append(node.action)
            node = node.parent
        plan.reverse()
        return plan

    def _get_priority(self, node):
        h = self._heuristic(node)
        if isinstance(h, tuple):
            return (tuple(node.g + hi for hi in h), h)
        return (node.g + h, h)


class BestFirstSearch(AStar):
    """Planning with best-first search
    """

    def _get_priority(self, node):
        h = self._heuristic(node)
        return h

# %% [markdown]
# ### Heuristics

# %%
class PyperplanHeuristic(Heuristic):
    """Don't worry about this -- it's just infrastructure connecting one library (PDDLGym) to another (Pyperplan)
    """
    def __init__(self, heuristic_name, domain):
        super().__init__()
        self._heuristic_name = heuristic_name
        self._domain = domain
        self._heuristic = None
        self._heuristic_goal = None
        self._actions = None

    def __call__(self, node):
        if node.state.goal != self._heuristic_goal:
            self._heuristic = self._initialize_heuristic(node.state)
            self._heuristic_goal = node.state.goal
        return self._heuristic(node.state)

    def set_actions(self, actions):
        self._actions = actions

    def train(self, env):
        pass
    
    def seed(self, seed):
        pass

    def _create_pyperplan_problem(self, state):
        try:
            problem_file = self._create_problem_file(state)
            parser = pyperplan.Parser(self._domain.domain_fname, problem_file)
            pyperplan_domain = parser.parse_domain()
            pyperplan_problem = parser.parse_problem(pyperplan_domain)
        finally:
            try:
                os.remove(problem_file)
            except FileNotFoundError:
                pass
        return pyperplan_problem

    def _create_problem_file(self, state):
        filename = tempfile.NamedTemporaryFile(delete=False).name
        lits = state.literals
        if not self._domain.operators_as_actions:
            lits |= set(self._actions)
        PDDLProblemParser.create_pddl_file(
            filename, state.objects-set(self._domain.constants), lits, 
            "myproblem", self._domain.domain_name, state.goal, fast_downward_order=True)
        return filename

    def _initialize_heuristic(self, state, cache_maxsize=10000):
        pyperplan_problem = self._create_pyperplan_problem(state)
        task = pyperplan.grounding.ground(pyperplan_problem)
        heuristic = pyperplan.HEURISTICS[self._heuristic_name](task)

        @functools.lru_cache(cache_maxsize)
        def _call_heuristic(state):
            state = frozenset({lit.pddl_str() for lit in state.literals})
            state &= task.facts
            node = pyperplan.search.searchspace.make_root_node(state)
            h = heuristic(node)
            return h

        return _call_heuristic

# %% [markdown]
# ### Registering approaches

# %%
def get_approach(name, env, planning_timeout=10):
    """Put new approaches here!
    """
    if name == "astar_uniform":
        planner = AStar(env.get_successor_state, env.check_goal, timeout=planning_timeout)
        return SearchApproach(planner=planner)
    
    if name == "astar_hmax":
        heuristic = PyperplanHeuristic("hmax", domain=env.domain)
        planner = AStar(env.get_successor_state, env.check_goal, heuristic=heuristic, timeout=planning_timeout)
        return SearchApproach(planner=planner)
    
    if name == "astar_hff":
        heuristic = PyperplanHeuristic("hff", domain=env.domain)
        planner = AStar(env.get_successor_state, env.check_goal, heuristic=heuristic, timeout=planning_timeout)
        return SearchApproach(planner=planner)
    
    if name == "astar_hadd":
        heuristic = PyperplanHeuristic("hadd", domain=env.domain)
        planner = AStar(env.get_successor_state, env.check_goal, heuristic=heuristic, timeout=planning_timeout)
        return SearchApproach(planner=planner)

    raise Exception(f"Unrecognized approach: {name}")

# Add your approach names here
approaches = [
    "astar_uniform",
    "astar_hmax",
    "astar_hff",
    "astar_hadd",
]

# %% [markdown]
# ### Evaluation Pipeline
# Here's all the code that you should need to evaluate your approaches.

# %%
def run_single_test(test_env, problem_idx, model, max_horizon=250, max_duration=10):
    print(f"Running test problem {problem_idx} in environment {test_env.spec.id}")
    test_env.fix_problem_index(problem_idx)
    start_time = time.time()
    obs, info = test_env.reset()
    model_info = model.reset(obs)
    node_expansions = model_info.get('node_expansions', 0)
    num_steps = 0
    success = False
    for t in range(max_horizon):
        if time.time() - start_time > max_duration:
            break
        print(".", end='', flush=True)
        act = model.step(obs)
        obs, reward, done, info = test_env.step(act)
        num_steps += 1
        if done:
            assert reward == 1
            success = True
            break
    duration = time.time() - start_time
    print(f" final duration: {duration} with num steps {num_steps} and success={success}.")
    return duration, num_steps, node_expansions, success

def run_single_experiment(model, train_env, test_env, seed=0):
    # Initialize
    test_env.reset()
    actions = test_env.get_possible_actions()
    model.set_actions(actions)
    model.seed(seed)
    
    # Training
    training_start_time = time.time()
    model.train(train_env)
    train_duration = time.time() - training_start_time
    train_durations = [train_duration] * len(test_env.problems) # for result reporting convenience

    # Test time
    test_durations = [] # seconds, one per problem
    test_num_steps = [] # integers
    test_node_expansions = [] # integers
    test_successes = [] # boolean, True if successful
    
    for problem_idx in range(len(test_env.problems)):
        duration, num_steps, node_expansions, success = \
            run_single_test(test_env, problem_idx, model)
        test_durations.append(duration)
        test_num_steps.append(num_steps)
        test_node_expansions.append(node_expansions)
        test_successes.append(success)

    return train_durations, test_durations, test_num_steps, test_node_expansions, test_successes

# %% [markdown]
# ### Here's where the action happens

# %%
levels = list(range(1, 7))

all_results = {}
for level in levels:
    all_results[level] = {}
    train_env = pddlgym.make(f"PDDLSearchAndRescueLevel{level}-v0")
    test_env = pddlgym.make(f"PDDLSearchAndRescueLevel{level}Test-v0")
    for approach in approaches:
        all_results[level][approach] = []
        model = get_approach(approach, test_env)
        results = run_single_experiment(model, train_env, test_env)
        for (train_dur, dur, num_steps, num_nodes, succ) in zip(*results):
            all_results[level][approach].append((train_dur, dur, num_steps, num_nodes, succ))
# Out:
# Running test problem 0 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 148
# Plan found!
# ......... final duration: 0.3566441535949707 with num steps 9 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 148
# Plan found!
# .......... final duration: 0.37461233139038086 with num steps 10 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 148
# Plan found!
# ............. final duration: 0.4298849105834961 with num steps 13 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 148
# Plan found!
# ............... final duration: 0.3606128692626953 with num steps 15 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 148
# Plan found!
# ........... final duration: 0.38443708419799805 with num steps 11 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 148
# Plan found!
# ........... final duration: 0.4485151767730713 with num steps 11 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 148
# Plan found!
# .......... final duration: 0.36606383323669434 with num steps 10 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 148
# Plan found!
# .............. final duration: 0.42864012718200684 with num steps 14 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 148
# Plan found!
# .............. final duration: 0.38338184356689453 with num steps 14 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 148
# Plan found!
# ......... final duration: 0.4172520637512207 with num steps 9 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 15
# Plan found!
# ......... final duration: 0.11990499496459961 with num steps 9 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 17
# Plan found!
# .......... final duration: 0.07152390480041504 with num steps 10 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 24
# Plan found!
# ............. final duration: 0.1099848747253418 with num steps 13 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 30
# Plan found!
# ............... final duration: 0.12109899520874023 with num steps 15 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 21
# Plan found!
# ........... final duration: 0.10377383232116699 with num steps 11 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 19
# Plan found!
# ........... final duration: 0.09684014320373535 with num steps 11 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 19
# Plan found!
# .......... final duration: 0.08548092842102051 with num steps 10 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 28
# Plan found!
# .............. final duration: 0.1157841682434082 with num steps 14 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 29
# Plan found!
# .............. final duration: 0.11401104927062988 with num steps 14 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 14
# Plan found!
# ......... final duration: 0.06579184532165527 with num steps 9 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 11
# Plan found!
# ......... final duration: 0.12927699089050293 with num steps 9 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 14
# Plan found!
# .......... final duration: 0.08124995231628418 with num steps 10 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 18
# Plan found!
# ............. final duration: 0.09162497520446777 with num steps 13 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 21
# Plan found!
# ............... final duration: 0.09744882583618164 with num steps 15 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 13
# Plan found!
# ........... final duration: 0.06498575210571289 with num steps 11 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 16
# Plan found!
# ........... final duration: 0.0794229507446289 with num steps 11 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 10
# Plan found!
# .......... final duration: 0.06175708770751953 with num steps 10 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 14
# Plan found!
# .............. final duration: 0.0915381908416748 with num steps 14 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 20
# Plan found!
# .............. final duration: 0.08144903182983398 with num steps 14 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 9
# Plan found!
# ......... final duration: 0.03218889236450195 with num steps 9 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 11
# Plan found!
# ......... final duration: 0.09293913841247559 with num steps 9 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 13
# Plan found!
# .......... final duration: 0.04315018653869629 with num steps 10 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 17
# Plan found!
# ............. final duration: 0.0581362247467041 with num steps 13 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 18
# Plan found!
# ............... final duration: 0.06313300132751465 with num steps 15 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 12
# Plan found!
# ........... final duration: 0.041799068450927734 with num steps 11 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 16
# Plan found!
# ........... final duration: 0.04936981201171875 with num steps 11 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 11
# Plan found!
# .......... final duration: 0.04369306564331055 with num steps 10 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 14
# Plan found!
# .............. final duration: 0.056250810623168945 with num steps 14 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 17
# Plan found!
# .............. final duration: 0.06402015686035156 with num steps 14 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel1Test-v0
# Expanding node 9
# Plan found!
# ......... final duration: 0.03934192657470703 with num steps 9 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 96
# Plan found!
# ............... final duration: 0.24471807479858398 with num steps 15 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 125
# Plan found!
# ........ final duration: 0.3182373046875 with num steps 8 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 280
# Plan found!
# ................ final duration: 0.7835111618041992 with num steps 16 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 148
# Plan found!
# .............. final duration: 0.3534352779388428 with num steps 14 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 330
# Plan found!
# ........... final duration: 0.7992801666259766 with num steps 11 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 45
# Plan found!
# ........... final duration: 0.1041100025177002 with num steps 11 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 408
# Plan found!
# .............. final duration: 0.9119560718536377 with num steps 14 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 408
# Plan found!
# ........... final duration: 0.8951449394226074 with num steps 11 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 337
# Plan found!
# ................ final duration: 0.7759590148925781 with num steps 16 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 96
# Plan found!
# ............. final duration: 0.23417091369628906 with num steps 13 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 29
# Plan found!
# ............... final duration: 0.15645694732666016 with num steps 15 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 12
# Plan found!
# ........ final duration: 0.0462338924407959 with num steps 8 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 33
# Plan found!
# ................ final duration: 0.11885285377502441 with num steps 16 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 35
# Plan found!
# .............. final duration: 0.12502288818359375 with num steps 14 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 20
# Plan found!
# ........... final duration: 0.07109498977661133 with num steps 11 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 17
# Plan found!
# ........... final duration: 0.0644218921661377 with num steps 11 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 29
# Plan found!
# .............. final duration: 0.15073108673095703 with num steps 14 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 20
# Plan found!
# ........... final duration: 0.08840489387512207 with num steps 11 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 37
# Plan found!
# ................ final duration: 0.1470179557800293 with num steps 16 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 27
# Plan found!
# ............. final duration: 0.0845799446105957 with num steps 13 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 18
# Plan found!
# ............... final duration: 0.11773920059204102 with num steps 15 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 10
# Plan found!
# ........ final duration: 0.03874993324279785 with num steps 8 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 22
# Plan found!
# ................ final duration: 0.10248780250549316 with num steps 16 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 21
# Plan found!
# ................ final duration: 0.09316682815551758 with num steps 16 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 13
# Plan found!
# ........... final duration: 0.05463123321533203 with num steps 11 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 12
# Plan found!
# ........... final duration: 0.05460977554321289 with num steps 11 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 25
# Plan found!
# .............. final duration: 0.11289787292480469 with num steps 14 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 11
# Plan found!
# ........... final duration: 0.04292798042297363 with num steps 11 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 23
# Plan found!
# ................ final duration: 0.09779024124145508 with num steps 16 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 15
# Plan found!
# ............. final duration: 0.05423712730407715 with num steps 13 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 17
# Plan found!
# ............... final duration: 0.1112678050994873 with num steps 15 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 10
# Plan found!
# ........ final duration: 0.03877520561218262 with num steps 8 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 22
# Plan found!
# ................ final duration: 0.09163284301757812 with num steps 16 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 21
# Plan found!
# ................ final duration: 0.0892641544342041 with num steps 16 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 13
# Plan found!
# ........... final duration: 0.055557966232299805 with num steps 11 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 12
# Plan found!
# ........... final duration: 0.04929375648498535 with num steps 11 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 25
# Plan found!
# .............. final duration: 0.10641694068908691 with num steps 14 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 11
# Plan found!
# ........... final duration: 0.041819095611572266 with num steps 11 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 23
# Plan found!
# ................ final duration: 0.09623193740844727 with num steps 16 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel2Test-v0
# Expanding node 15
# Plan found!
# ............. final duration: 0.05411195755004883 with num steps 13 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 225
# Plan found!
# .............. final duration: 0.5426490306854248 with num steps 14 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 30
# Plan found!
# ....... final duration: 0.07060813903808594 with num steps 7 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 63
# Plan found!
# ........... final duration: 0.1480998992919922 with num steps 11 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 307
# Plan found!
# ........... final duration: 0.6793179512023926 with num steps 11 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 105
# Plan found!
# .......... final duration: 0.23688292503356934 with num steps 10 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 109
# Plan found!
# ........... final duration: 0.24468302726745605 with num steps 11 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 235
# Plan found!
# ............. final duration: 0.51869797706604 with num steps 13 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 45
# Plan found!
# .......... final duration: 0.1077260971069336 with num steps 10 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 109
# Plan found!
# .......... final duration: 0.2550048828125 with num steps 10 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 194
# Plan found!
# ............ final duration: 0.5120339393615723 with num steps 12 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 33
# Plan found!
# .............. final duration: 0.17821192741394043 with num steps 14 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 9
# Plan found!
# ....... final duration: 0.08170175552368164 with num steps 7 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 17
# Plan found!
# ........... final duration: 0.11825275421142578 with num steps 11 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 22
# Plan found!
# ........... final duration: 0.21304774284362793 with num steps 11 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 18
# Plan found!
# .......... final duration: 0.1186380386352539 with num steps 10 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 21
# Plan found!
# ........... final duration: 0.1336078643798828 with num steps 11 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 27
# Plan found!
# ............. final duration: 0.15440893173217773 with num steps 13 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 11
# Plan found!
# .......... final duration: 0.09529423713684082 with num steps 10 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 18
# Plan found!
# .......... final duration: 0.12714099884033203 with num steps 10 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 26
# Plan found!
# ............ final duration: 0.16634798049926758 with num steps 12 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 21
# Plan found!
# ................ final duration: 0.15082693099975586 with num steps 16 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 7
# Plan found!
# ....... final duration: 0.07964015007019043 with num steps 7 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 11
# Plan found!
# ........... final duration: 0.10524868965148926 with num steps 11 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 14
# Plan found!
# ........... final duration: 0.12564873695373535 with num steps 11 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 16
# Plan found!
# .......... final duration: 0.12090706825256348 with num steps 10 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 15
# Plan found!
# ........... final duration: 0.11903715133666992 with num steps 11 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 16
# Plan found!
# ............. final duration: 0.12602782249450684 with num steps 13 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 10
# Plan found!
# .......... final duration: 0.1008458137512207 with num steps 10 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 10
# Plan found!
# .......... final duration: 0.10488295555114746 with num steps 10 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 20
# Plan found!
# ............ final duration: 0.1471400260925293 with num steps 12 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 22
# Plan found!
# ................ final duration: 0.15315604209899902 with num steps 16 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 7
# Plan found!
# ....... final duration: 0.07906103134155273 with num steps 7 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 11
# Plan found!
# ........... final duration: 0.09844779968261719 with num steps 11 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 14
# Plan found!
# ........... final duration: 0.12009716033935547 with num steps 11 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 15
# Plan found!
# .......... final duration: 0.11838412284851074 with num steps 10 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 12
# Plan found!
# ........... final duration: 0.10133671760559082 with num steps 11 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 16
# Plan found!
# ............. final duration: 0.11160111427307129 with num steps 13 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 10
# Plan found!
# .......... final duration: 0.0841829776763916 with num steps 10 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 10
# Plan found!
# .......... final duration: 0.0888671875 with num steps 10 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel3Test-v0
# Expanding node 20
# Plan found!
# ............ final duration: 0.1289510726928711 with num steps 12 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 269
# Plan found!
# ............ final duration: 0.7472009658813477 with num steps 12 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 443
# Plan found!
# ......... final duration: 1.2013258934020996 with num steps 9 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 884
# Plan found!
# ............. final duration: 2.4759840965270996 with num steps 13 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 442
# Plan found!
# ............ final duration: 1.189697027206421 with num steps 12 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 390
# Plan found!
# ........... final duration: 1.0768449306488037 with num steps 11 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 214
# Plan found!
# ......... final duration: 0.5756328105926514 with num steps 9 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel4Test-v0
# Warning: planning failed.
#  final duration: 10.016772031784058 with num steps 0 and success=False.
# Running test problem 7 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 516
# Plan found!
# ......... final duration: 1.3751180171966553 with num steps 9 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 3013
# Plan found!
# ............. final duration: 8.659147024154663 with num steps 13 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 282
# Plan found!
# .......... final duration: 0.7852458953857422 with num steps 10 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 24
# Plan found!
# ............ final duration: 0.1437687873840332 with num steps 12 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 19
# Plan found!
# ......... final duration: 0.15870094299316406 with num steps 9 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 31
# Plan found!
# ............. final duration: 0.25896596908569336 with num steps 13 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 24
# Plan found!
# ............ final duration: 0.17058610916137695 with num steps 12 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 18
# Plan found!
# ........... final duration: 0.12986111640930176 with num steps 11 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 16
# Plan found!
# ......... final duration: 0.11734414100646973 with num steps 9 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 217
# Plan found!
# ............... final duration: 1.077937126159668 with num steps 15 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 19
# Plan found!
# ......... final duration: 0.1422111988067627 with num steps 9 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 124
# Plan found!
# ............. final duration: 0.6940069198608398 with num steps 13 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 17
# Plan found!
# .......... final duration: 0.12012481689453125 with num steps 10 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 22
# Plan found!
# ............ final duration: 0.14085674285888672 with num steps 12 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 9
# Plan found!
# ......... final duration: 0.09497690200805664 with num steps 9 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 19
# Plan found!
# ............. final duration: 0.14712977409362793 with num steps 13 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 20
# Plan found!
# .............. final duration: 0.16127419471740723 with num steps 14 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 17
# Plan found!
# ........... final duration: 0.13011622428894043 with num steps 11 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 10
# Plan found!
# ......... final duration: 0.09473109245300293 with num steps 9 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 45
# Plan found!
# ............... final duration: 0.2965819835662842 with num steps 15 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 11
# Plan found!
# ......... final duration: 0.10682511329650879 with num steps 9 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 27
# Plan found!
# ............. final duration: 0.22119402885437012 with num steps 13 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 13
# Plan found!
# .......... final duration: 0.10815310478210449 with num steps 10 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 15
# Plan found!
# ............ final duration: 0.11325430870056152 with num steps 12 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 11
# Plan found!
# ......... final duration: 0.11109471321105957 with num steps 9 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 17
# Plan found!
# ............. final duration: 0.17617297172546387 with num steps 13 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 19
# Plan found!
# .............. final duration: 0.19404077529907227 with num steps 14 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 17
# Plan found!
# ........... final duration: 0.20744919776916504 with num steps 11 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 10
# Plan found!
# ......... final duration: 0.10886621475219727 with num steps 9 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 42
# Plan found!
# ............... final duration: 0.34807515144348145 with num steps 15 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 11
# Plan found!
# ......... final duration: 0.11434602737426758 with num steps 9 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 26
# Plan found!
# ............. final duration: 0.20621705055236816 with num steps 13 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel4Test-v0
# Expanding node 13
# Plan found!
# .......... final duration: 0.13101816177368164 with num steps 10 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel5Test-v0
# Warning: planning failed.
#  final duration: 10.014952898025513 with num steps 0 and success=False.
# Running test problem 1 in environment PDDLSearchAndRescueLevel5Test-v0
# Warning: planning failed.
#  final duration: 10.015472888946533 with num steps 0 and success=False.
# Running test problem 2 in environment PDDLSearchAndRescueLevel5Test-v0
# Warning: planning failed.
#  final duration: 10.015727043151855 with num steps 0 and success=False.
# Running test problem 3 in environment PDDLSearchAndRescueLevel5Test-v0
# Warning: planning failed.
#  final duration: 10.013349771499634 with num steps 0 and success=False.
# Running test problem 4 in environment PDDLSearchAndRescueLevel5Test-v0
# Warning: planning failed.
#  final duration: 10.015334129333496 with num steps 0 and success=False.
# Running test problem 5 in environment PDDLSearchAndRescueLevel5Test-v0
# Warning: planning failed.
#  final duration: 10.015475034713745 with num steps 0 and success=False.
# Running test problem 6 in environment PDDLSearchAndRescueLevel5Test-v0
# Warning: planning failed.
#  final duration: 10.015951156616211 with num steps 0 and success=False.
# Running test problem 7 in environment PDDLSearchAndRescueLevel5Test-v0
# Warning: planning failed.
#  final duration: 10.015969038009644 with num steps 0 and success=False.
# Running test problem 8 in environment PDDLSearchAndRescueLevel5Test-v0
# Warning: planning failed.
#  final duration: 10.017940044403076 with num steps 0 and success=False.
# Running test problem 9 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 1068
# Plan found!
# ............ final duration: 3.579024314880371 with num steps 12 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel5Test-v0
# Warning: planning failed.
#  final duration: 10.004136800765991 with num steps 0 and success=False.
# Running test problem 1 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 1178
# Plan found!
# .................. final duration: 6.58003044128418 with num steps 18 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel5Test-v0
# Warning: planning failed.
#  final duration: 10.004824161529541 with num steps 0 and success=False.
# Running test problem 3 in environment PDDLSearchAndRescueLevel5Test-v0
# Warning: planning failed.
#  final duration: 10.001432180404663 with num steps 0 and success=False.
# Running test problem 4 in environment PDDLSearchAndRescueLevel5Test-v0
# Warning: planning failed.
#  final duration: 10.004537105560303 with num steps 0 and success=False.
# Running test problem 5 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 320
# Plan found!
# ............... final duration: 1.7784287929534912 with num steps 15 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 278
# Plan found!
# ............. final duration: 1.5794439315795898 with num steps 13 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel5Test-v0
# Warning: planning failed.
#  final duration: 10.002454042434692 with num steps 0 and success=False.
# Running test problem 8 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 514
# Plan found!
# ................ final duration: 2.93143892288208 with num steps 16 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 42
# Plan found!
# ............ final duration: 0.2644517421722412 with num steps 12 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel5Test-v0
# Warning: planning failed.
#  final duration: 10.0016930103302 with num steps 0 and success=False.
# Running test problem 1 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 82
# Plan found!
# .................. final duration: 0.535179853439331 with num steps 18 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 285
# Plan found!
# ...................... final duration: 1.6433520317077637 with num steps 22 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel5Test-v0
# Warning: planning failed.
#  final duration: 10.00816011428833 with num steps 0 and success=False.
# Running test problem 4 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 203
# Plan found!
# ....................... final duration: 1.132775068283081 with num steps 23 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 41
# Plan found!
# ............... final duration: 0.2779240608215332 with num steps 15 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 31
# Plan found!
# ............. final duration: 0.2927069664001465 with num steps 13 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 582
# Plan found!
# ......................... final duration: 3.2895541191101074 with num steps 25 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 134
# Plan found!
# .................. final duration: 0.8137731552124023 with num steps 18 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 22
# Plan found!
# ............ final duration: 0.191741943359375 with num steps 12 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 425
# Plan found!
# ................................. final duration: 2.387509822845459 with num steps 33 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 59
# Plan found!
# .................. final duration: 0.37798094749450684 with num steps 18 and success=True.
# Running test problem 2 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 304
# Plan found!
# .................................. final duration: 1.8049449920654297 with num steps 34 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 249
# Plan found!
# ........................................ final duration: 1.45609712600708 with num steps 40 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 311
# Plan found!
# ....................... final duration: 1.8481781482696533 with num steps 23 and success=True.
# Running test problem 5 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 26
# Plan found!
# ............... final duration: 0.19613909721374512 with num steps 15 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 16
# Plan found!
# ............. final duration: 0.1529831886291504 with num steps 13 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 159
# Plan found!
# ......................... final duration: 0.9734468460083008 with num steps 25 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 44
# Plan found!
# .................. final duration: 0.31520938873291016 with num steps 18 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel5Test-v0
# Expanding node 21
# Plan found!
# ................ final duration: 0.17897582054138184 with num steps 16 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 2317
# Plan found!
# ............. final duration: 6.710396766662598 with num steps 13 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.015068292617798 with num steps 0 and success=False.
# Running test problem 2 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.01183009147644 with num steps 0 and success=False.
# Running test problem 3 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.015635013580322 with num steps 0 and success=False.
# Running test problem 4 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.011668920516968 with num steps 0 and success=False.
# Running test problem 5 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.017466068267822 with num steps 0 and success=False.
# Running test problem 6 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.014433145523071 with num steps 0 and success=False.
# Running test problem 7 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.01785397529602 with num steps 0 and success=False.
# Running test problem 8 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.015162229537964 with num steps 0 and success=False.
# Running test problem 9 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.017173051834106 with num steps 0 and success=False.
# Running test problem 0 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 126
# Plan found!
# ............. final duration: 0.6855401992797852 with num steps 13 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.002448320388794 with num steps 0 and success=False.
# Running test problem 2 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 400
# Plan found!
# ................... final duration: 1.97287917137146 with num steps 19 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.004547834396362 with num steps 0 and success=False.
# Running test problem 4 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.005670070648193 with num steps 0 and success=False.
# Running test problem 5 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.000816106796265 with num steps 0 and success=False.
# Running test problem 6 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.002503871917725 with num steps 0 and success=False.
# Running test problem 7 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.004918098449707 with num steps 0 and success=False.
# Running test problem 8 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.002990007400513 with num steps 0 and success=False.
# Running test problem 9 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 1727
# Plan found!
# ................. final duration: 8.914770126342773 with num steps 17 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 25
# Plan found!
# ............. final duration: 0.1889791488647461 with num steps 13 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.00230097770691 with num steps 0 and success=False.
# Running test problem 2 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 54
# Plan found!
# ................... final duration: 0.4229869842529297 with num steps 19 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 376
# Plan found!
# ........................... final duration: 2.1804888248443604 with num steps 27 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.005168914794922 with num steps 0 and success=False.
# Running test problem 5 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 187
# Plan found!
# .................. final duration: 1.1804261207580566 with num steps 18 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 250
# Plan found!
# ........................ final duration: 1.4929132461547852 with num steps 24 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.005917072296143 with num steps 0 and success=False.
# Running test problem 8 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 246
# Plan found!
# ......................... final duration: 1.409769058227539 with num steps 25 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 245
# Plan found!
# ................. final duration: 1.3990800380706787 with num steps 17 and success=True.
# Running test problem 0 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 18
# Plan found!
# ............... final duration: 0.1473841667175293 with num steps 15 and success=True.
# Running test problem 1 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.004759073257446 with num steps 0 and success=False.
# Running test problem 2 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 78
# Plan found!
# ....................... final duration: 0.48377084732055664 with num steps 23 and success=True.
# Running test problem 3 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 49
# Plan found!
# ........................... final duration: 0.2993736267089844 with num steps 27 and success=True.
# Running test problem 4 in environment PDDLSearchAndRescueLevel6Test-v0
# Warning: planning failed.
#  final duration: 10.00429105758667 with num steps 0 and success=False.
# Running test problem 5 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 49
# Plan found!
# ...................... final duration: 0.3611619472503662 with num steps 22 and success=True.
# Running test problem 6 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 92
# Plan found!
# .......................... final duration: 0.5513691902160645 with num steps 26 and success=True.
# Running test problem 7 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 345
# Plan found!
# .................................. final duration: 2.0421030521392822 with num steps 34 and success=True.
# Running test problem 8 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 161
# Plan found!
# ................................... final duration: 0.8874561786651611 with num steps 35 and success=True.
# Running test problem 9 in environment PDDLSearchAndRescueLevel6Test-v0
# Expanding node 24
# Plan found!
# ................. final duration: 0.1850879192352295 with num steps 17 and success=True.

# %%
columns = ["Approach", "Train Time", "Duration", "Num Steps", "Num Nodes", "Successes"]

for level in sorted(all_results):
    print(f"\n### LEVEL {level} ###")
    mean_table = [(a, ) + tuple(np.mean(all_results[level][a], axis=0)) for a in sorted(all_results[level])]
    std_table = [(a, ) + tuple(np.std(all_results[level][a], axis=0)) for a in sorted(all_results[level])]
    print("\n# Means #")
    print(tabulate(mean_table, headers=columns))
#     print("\n# Standard Deviations #")
#     print(tabulate(std_table, headers=columns))
# Out:
# ### LEVEL 1 ###
#
# # Means #
# Approach         Train Time    Duration    Num Steps    Num Nodes    Successes
# -------------  ------------  ----------  -----------  -----------  -----------
# astar_hadd      2.14577e-06   0.0551833         11.6         13.8            1
# astar_hff       1.90735e-06   0.0810943         11.6         14.6            1
# astar_hmax      9.53674e-07   0.100419          11.6         21.6            1
# astar_uniform   9.53674e-07   0.395004          11.6        148              1
#
# ### LEVEL 2 ###
#
# # Means #
# Approach         Train Time    Duration    Num Steps    Num Nodes    Successes
# -------------  ------------  ----------  -----------  -----------  -----------
# astar_hadd      2.14577e-06   0.0734372         13.1         16.9            1
# astar_hff       1.19209e-06   0.0769238         13.1         17              1
# astar_hmax      1.90735e-06   0.105282          12.9         25.9            1
# astar_uniform   1.19209e-06   0.542052          12.9        227.3            1
#
# ### LEVEL 3 ###
#
# # Means #
# Approach         Train Time    Duration    Num Steps    Num Nodes    Successes
# -------------  ------------  ----------  -----------  -----------  -----------
# astar_hadd      9.53674e-07    0.108409         11.1         13.7            1
# astar_hff       6.91414e-06    0.118021         11.1         14              1
# astar_hmax      1.19209e-06    0.138665         10.9         20.2            1
# astar_uniform   9.53674e-07    0.33157          10.9        142.2            1
#
# ### LEVEL 4 ###
#
# # Means #
# Approach         Train Time    Duration    Num Steps    Num Nodes    Successes
# -------------  ------------  ----------  -----------  -----------  -----------
# astar_hadd      9.53674e-07    0.171053         11.5         18.1          1
# astar_hff       1.19209e-06    0.150184         11.5         19.3          1
# astar_hmax      7.15256e-07    0.301351         11.3         50.9          1
# astar_uniform   9.53674e-07    2.8103            9.8       1020.2          0.9
#
# ### LEVEL 5 ###
#
# # Means #
# Approach         Train Time    Duration    Num Steps    Num Nodes    Successes
# -------------  ------------  ----------  -----------  -----------  -----------
# astar_hadd      9.53674e-07    0.969147         23.5        161.4          1
# astar_hff       9.53674e-07    2.81869          14.6        495.7          0.8
# astar_hmax      1.19209e-06    6.31512           7.4       1125.4          0.5
# astar_uniform   1.90735e-06    9.37192           1.2       3394.2          0.1
#
# ### LEVEL 6 ###
#
# # Means #
# Approach         Train Time    Duration    Num Steps    Num Nodes    Successes
# -------------  ------------  ----------  -----------  -----------  -----------
# astar_hadd      9.53674e-07     2.49668         19.9        479.7          0.8
# astar_hff       9.53674e-07     3.8288          14.3        649.6          0.7
# astar_hmax      1.19209e-06     8.15971          4.9       1517.8          0.3
# astar_uniform   9.53674e-07     9.68467          1.3       3334.7          0.1
